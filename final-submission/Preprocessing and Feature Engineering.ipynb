# %%
# Modules
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Import Data
df = pd.read_csv("df_imputed.csv")
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  months_as_customer  age  policy_number  \
# 0                0           0                 267   40         426708
# 1                1           1                 322   44         769602
# 2                2           2                 259   45         608443
# 3                3           3                 446   61         259792
# 4                4           4                 134   29         687698
# ...            ...         ...                 ...  ...            ...
# 1724          1724        1724                  85   25         159768
# 1725          1725        1725                 131   33         432740
# 1726          1726        1726                 194   35         275092
# 1727          1727        1727                 210   37         218684
# 1728          1728        1728                  86   28         613226
#
#      policy_bind_date policy_state policy_csl  policy_deductable  \
# 0          2009-10-09           IL    250/500                500
# 1          2004-12-19           IL    100/300               1000
# 2          2006-12-21           IL   500/1000               2000
# 3          1999-04-07           IL    100/300               1000
# 4          2000-09-06           OH    100/300               2000
# ...               ...          ...        ...                ...
# 1724       2008-09-03           IN    250/500                500
# 1725       1990-10-09           IL    100/300               2000
# 1726       2012-03-14           IL   500/1000                500
# 1727       2006-08-05           IN   500/1000               2000
# 1728       1991-08-22           IN    100/300               2000
#
#       policy_annual_premium  ...  police_report_available  total_claim_amount  \
# 0                   1155.53  ...                       NO                5670
# 1                   1156.19  ...                        ?               49400
# 2                   1175.07  ...                       NO               87780
# 3                   1232.79  ...                      YES               70500
# 4                   1413.14  ...                       NO               34650
# ...                     ...  ...                      ...                 ...
# 1724                1259.02  ...                        ?                5640
# 1725                1081.17  ...                       NO                4900
# 1726                1416.24  ...                        ?                5940
# 1727                1048.46  ...                        ?                7080
# 1728                1595.07  ...                      YES               70920
#
#      injury_claim property_claim vehicle_claim auto_make  auto_model  \
# 0            1260            630          3780      Ford        F150
# 1            9880           4940         34580      Jeep    Wrangler
# 2            7980           7980         71820     Honda         CRV
# 3            7050          14100         49350    Suburu   Forrestor
# 4            7700           3850         23100     Dodge         RAM
# ...           ...            ...           ...       ...         ...
# 1724          940            940          3760    Nissan      Ultima
# 1725          490            490          3920    Toyota       Camry
# 1726         1080            540          4320    Nissan  Pathfinder
# 1727         1180            590          5310     Dodge         RAM
# 1728        11820          11820         47280      Jeep    Wrangler
#
#       auto_year  fraud_reported _c39
# 0          1997               N  NaN
# 1          2010               N  NaN
# 2          2011               N  NaN
# 3          2007               N  NaN
# 4          2007               N  NaN
# ...         ...             ...  ...
# 1724       2005               N  NaN
# 1725       2010               N  NaN
# 1726       2003               N  NaN
# 1727       1999               N  NaN
# 1728       2002               N  NaN
#
# [1729 rows x 42 columns]

# %%
# Drop columns
df = df.drop(columns=['Unnamed: 0.1','Unnamed: 0'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1729 entries, 0 to 1728
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1729 non-null   int64
#  1   age                          1729 non-null   int64
#  2   policy_number                1729 non-null   int64
#  3   policy_bind_date             1729 non-null   object
#  4   policy_state                 1729 non-null   object
#  5   policy_csl                   1729 non-null   object
#  6   policy_deductable            1729 non-null   int64
#  7   policy_annual_premium        1729 non-null   float64
#  8   umbrella_limit               1729 non-null   int64
#  9   insured_zip                  1729 non-null   int64
#  10  insured_sex                  1729 non-null   object
#  11  insured_education_level      1729 non-null   object
#  12  insured_occupation           1729 non-null   object
#  13  insured_hobbies              1729 non-null   object
#  14  insured_relationship         1729 non-null   object
#  15  capital-gains                1729 non-null   int64
#  16  capital-loss                 1729 non-null   int64
#  17  incident_date                1729 non-null   object
#  18  incident_type                1729 non-null   object
#  19  collision_type               1729 non-null   object
#  20  incident_severity            1729 non-null   object
#  21  authorities_contacted        1729 non-null   object
#  22  incident_state               1729 non-null   object
#  23  incident_city                1729 non-null   object
#  24  incident_location            1729 non-null   object
#  25  incident_hour_of_the_day     1729 non-null   int64
#  26  number_of_vehicles_involved  1729 non-null   int64
#  27  property_damage              1729 non-null   object
#  28  bodily_injuries              1729 non-null   int64
#  29  witnesses                    1729 non-null   int64
#  30  police_report_available      1729 non-null   object
#  31  total_claim_amount           1729 non-null   int64
#  32  injury_claim                 1729 non-null   int64
#  33  property_claim               1729 non-null   int64
#  34  vehicle_claim                1729 non-null   int64
#  35  auto_make                    1729 non-null   object
#  36  auto_model                   1729 non-null   object
#  37  auto_year                    1729 non-null   int64
#  38  fraud_reported               1729 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 540.4+ KB

# %%
# Data Preprocessing
# policy_state
# Group by policy_number and count occurrences
frequency = df.groupby('policy_number').size().reset_index(name='frequency')

# Merge the frequency column back to the original dataframe
df = pd.merge(df, frequency, on='policy_number', how='left')
df = df.drop(columns=['policy_number'])
df
# Out:
#       months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                    267   40       2009-10-09           IL    250/500
# 1                    322   44       2004-12-19           IL    100/300
# 2                    259   45       2006-12-21           IL   500/1000
# 3                    446   61       1999-04-07           IL    100/300
# 4                    134   29       2000-09-06           OH    100/300
# ...                  ...  ...              ...          ...        ...
# 1724                  85   25       2008-09-03           IN    250/500
# 1725                 131   33       1990-10-09           IL    100/300
# 1726                 194   35       2012-03-14           IL   500/1000
# 1727                 210   37       2006-08-05           IN   500/1000
# 1728                  86   28       1991-08-22           IN    100/300
#
#       policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                   500                1155.53         5000000       465158
# 1                  1000                1156.19               0       606249
# 2                  2000                1175.07               0       457121
# 3                  1000                1232.79               0       441967
# 4                  2000                1413.14         5000000       430632
# ...                 ...                    ...             ...          ...
# 1724                500                1259.02               0       439534
# 1725               2000                1081.17               0       445120
# 1726                500                1416.24               0       441659
# 1727               2000                1048.46               0       466676
# 1728               2000                1595.07               0       439304
#
#      insured_sex  ... total_claim_amount injury_claim property_claim  \
# 0           MALE  ...               5670         1260            630
# 1         FEMALE  ...              49400         9880           4940
# 2           MALE  ...              87780         7980           7980
# 3         FEMALE  ...              70500         7050          14100
# 4         FEMALE  ...              34650         7700           3850
# ...          ...  ...                ...          ...            ...
# 1724      FEMALE  ...               5640          940            940
# 1725        MALE  ...               4900          490            490
# 1726      FEMALE  ...               5940         1080            540
# 1727        MALE  ...               7080         1180            590
# 1728        MALE  ...              70920        11820          11820
#
#      vehicle_claim  auto_make  auto_model auto_year fraud_reported _c39  \
# 0             3780       Ford        F150      1997              N  NaN
# 1            34580       Jeep    Wrangler      2010              N  NaN
# 2            71820      Honda         CRV      2011              N  NaN
# 3            49350     Suburu   Forrestor      2007              N  NaN
# 4            23100      Dodge         RAM      2007              N  NaN
# ...            ...        ...         ...       ...            ...  ...
# 1724          3760     Nissan      Ultima      2005              N  NaN
# 1725          3920     Toyota       Camry      2010              N  NaN
# 1726          4320     Nissan  Pathfinder      2003              N  NaN
# 1727          5310      Dodge         RAM      1999              N  NaN
# 1728         47280       Jeep    Wrangler      2002              N  NaN
#
#      frequency
# 0            4
# 1            3
# 2            1
# 3            1
# 4            4
# ...        ...
# 1724         3
# 1725         2
# 1726         3
# 1727         1
# 1728         2
#
# [1729 rows x 40 columns]

# %%
# Policy bind date
# Convert 'policy_bind_date' to datetime type
df['policy_bind_date'] = pd.to_datetime(df['policy_bind_date'])

# Extract year, month, date, and day of the week
df['year_bind'] = df['policy_bind_date'].dt.year
df['month_bind'] = df['policy_bind_date'].dt.month
df['date_bind'] = df['policy_bind_date'].dt.day
df['day_of_week_bind'] = df['policy_bind_date'].dt.dayofweek  # Monday=0, Sunday=6

# Map day_of_week to actual day names
df['day_of_week_bind'] = df['policy_bind_date'].dt.day_name()

# Create a column indicating weekend (Saturday or Sunday)
df['is_weekend_bind'] = df['policy_bind_date'].dt.dayofweek.isin([5, 6]).astype(int)
df = df.drop(columns=['policy_bind_date'])
df
# Out:
#       months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                    267   40           IL    250/500                500
# 1                    322   44           IL    100/300               1000
# 2                    259   45           IL   500/1000               2000
# 3                    446   61           IL    100/300               1000
# 4                    134   29           OH    100/300               2000
# ...                  ...  ...          ...        ...                ...
# 1724                  85   25           IN    250/500                500
# 1725                 131   33           IL    100/300               2000
# 1726                 194   35           IL   500/1000                500
# 1727                 210   37           IN   500/1000               2000
# 1728                  86   28           IN    100/300               2000
#
#       policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# 0                   1155.53         5000000       465158        MALE
# 1                   1156.19               0       606249      FEMALE
# 2                   1175.07               0       457121        MALE
# 3                   1232.79               0       441967      FEMALE
# 4                   1413.14         5000000       430632      FEMALE
# ...                     ...             ...          ...         ...
# 1724                1259.02               0       439534      FEMALE
# 1725                1081.17               0       445120        MALE
# 1726                1416.24               0       441659      FEMALE
# 1727                1048.46               0       466676        MALE
# 1728                1595.07               0       439304        MALE
#
#      insured_education_level  ...  auto_model auto_year fraud_reported  _c39  \
# 0                         JD  ...        F150      1997              N   NaN
# 1                    College  ...    Wrangler      2010              N   NaN
# 2                         MD  ...         CRV      2011              N   NaN
# 3                High School  ...   Forrestor      2007              N   NaN
# 4                        PhD  ...         RAM      2007              N   NaN
# ...                      ...  ...         ...       ...            ...   ...
# 1724                      JD  ...      Ultima      2005              N   NaN
# 1725                      MD  ...       Camry      2010              N   NaN
# 1726                      MD  ...  Pathfinder      2003              N   NaN
# 1727             High School  ...         RAM      1999              N   NaN
# 1728                     PhD  ...    Wrangler      2002              N   NaN
#
#       frequency year_bind month_bind date_bind day_of_week_bind  \
# 0             4      2009         10         9           Friday
# 1             3      2004         12        19           Sunday
# 2             1      2006         12        21         Thursday
# 3             1      1999          4         7        Wednesday
# 4             4      2000          9         6        Wednesday
# ...         ...       ...        ...       ...              ...
# 1724          3      2008          9         3        Wednesday
# 1725          2      1990         10         9          Tuesday
# 1726          3      2012          3        14        Wednesday
# 1727          1      2006          8         5         Saturday
# 1728          2      1991          8        22         Thursday
#
#      is_weekend_bind
# 0                  0
# 1                  1
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 1724               0
# 1725               0
# 1726               0
# 1727               1
# 1728               0
#
# [1729 rows x 44 columns]

# %%
# Policy State
df = pd.get_dummies(df, columns=['policy_state'], prefix='policy_state')

# Policy csl
df = pd.get_dummies(df, columns=['policy_csl'], prefix='policy_csl')

# Umbrella limit
df['umbrella_limit_indicator'] = (df['umbrella_limit'] != 0).astype(int)


# Group by insured_zip and count occurrences
frequency = df.groupby('insured_zip').size().reset_index(name='frequency_zip')

# Merge the frequency column back to the original dataframe
df = pd.merge(df, frequency, on='insured_zip', how='left')

# insured_sex
df = pd.get_dummies(df, columns=['insured_sex'], prefix='sex')

# insured_education_level
df = pd.get_dummies(df, columns=['insured_education_level'], prefix='education')

# insured_occupation
df = pd.get_dummies(df, columns=['insured_occupation'], prefix='occupation')

# insured_hobbies
df = pd.get_dummies(df, columns=['insured_hobbies'], prefix='hobbies')

#insured_relationship
df = pd.get_dummies(df, columns=['insured_relationship'], prefix='relationship')

# capital-gain
df['capital-gain_indicator'] = (df['capital-gains'] != 0).astype(int)

#incident_date
# Convert 'policy_bind_date' to datetime type
df['incident_date'] = pd.to_datetime(df['incident_date'])

# Extract year, month, date, and day of the week
df['year_incident'] = df['incident_date'].dt.year
df['month_incident'] = df['incident_date'].dt.month
df['date_incident'] = df['incident_date'].dt.day
df['day_of_week_incident'] = df['incident_date'].dt.dayofweek  # Monday=0, Sunday=6

# Map day_of_week to actual day names
df['day_of_week_incident'] = df['incident_date'].dt.day_name()

# Create a column indicating weekend (Saturday or Sunday)
df['is_weekend_incident'] = df['incident_date'].dt.dayofweek.isin([5, 6]).astype(int)
df = df.drop(columns=['incident_date'])


#incident_type
df = pd.get_dummies(df, columns=['incident_type'], prefix='incident')


# Collision_type
df = pd.get_dummies(df, columns=['collision_type'], prefix='collision')


# incident_severity
ordinal_mapping = {'Trivial Damage': 1, 'Minor Damage': 2, 'Major Damage': 3, "Total Loss" : 4}
df['incident_severity'] = df['incident_severity'].map(ordinal_mapping)

# authorities_contacted
df = pd.get_dummies(df, columns=['authorities_contacted'], prefix='auth')


# incident State
df = pd.get_dummies(df, columns=['incident_state'], prefix='incident_state')


# incident city
df = pd.get_dummies(df, columns=['incident_city'], prefix='incident_city')


# incident_location
df = df.drop(columns=['incident_location'])

# Property damage
df = pd.get_dummies(df, columns=['property_damage'], prefix='property_damge')


# Police_report_available
df = pd.get_dummies(df, columns=['police_report_available'], prefix='police')


# total_claim_amount
df['total_claim_amount_indicator'] = (df['total_claim_amount'] >= 20000).astype(int)
df['injury_claim_amount_indicator'] = (df['injury_claim'] >= 3000).astype(int)
df['property_claim_amount_indicator'] = (df['property_claim'] >= 3000).astype(int)
df['vehicle_claim_amount_indicator'] = (df['vehicle_claim'] >= 10000).astype(int)

#Auto
df = pd.get_dummies(df, columns=['auto_make'], prefix='make')

df = pd.get_dummies(df, columns=['auto_model'], prefix='auto_model')


# Fraud
df['fraud_reported'] = df['fraud_reported'].replace({'Y': 1, 'N': 0})

df
# Out:
#       months_as_customer  age  policy_deductable  policy_annual_premium  \
# 0                    267   40                500                1155.53
# 1                    322   44               1000                1156.19
# 2                    259   45               2000                1175.07
# 3                    446   61               1000                1232.79
# 4                    134   29               2000                1413.14
# ...                  ...  ...                ...                    ...
# 1724                  85   25                500                1259.02
# 1725                 131   33               2000                1081.17
# 1726                 194   35                500                1416.24
# 1727                 210   37               2000                1048.46
# 1728                  86   28               2000                1595.07
#
#       umbrella_limit  insured_zip  capital-gains  capital-loss  \
# 0            5000000       465158              0        -35200
# 1                  0       606249          49900        -62700
# 2                  0       457121          30100             0
# 3                  0       441967          49900        -62100
# 4            5000000       430632          35100             0
# ...              ...          ...            ...           ...
# 1724               0       439534          67000        -53600
# 1725               0       445120              0        -65200
# 1726               0       441659              0             0
# 1727               0       466676          59900             0
# 1728               0       439304          75800             0
#
#       incident_severity  incident_hour_of_the_day  ...  auto_model_Pathfinder  \
# 0                     1                         5  ...                  False
# 1                     3                        20  ...                  False
# 2                     2                        23  ...                  False
# 3                     2                         3  ...                  False
# 4                     2                         7  ...                  False
# ...                 ...                       ...  ...                    ...
# 1724                  1                         8  ...                  False
# 1725                  2                         3  ...                  False
# 1726                  2                         7  ...                   True
# 1727                  1                         9  ...                  False
# 1728                  2                        19  ...                  False
#
#       auto_model_RAM  auto_model_RSX  auto_model_Silverado  auto_model_TL  \
# 0              False           False                 False          False
# 1              False           False                 False          False
# 2              False           False                 False          False
# 3              False           False                 False          False
# 4               True           False                 False          False
# ...              ...             ...                   ...            ...
# 1724           False           False                 False          False
# 1725           False           False                 False          False
# 1726           False           False                 False          False
# 1727            True           False                 False          False
# 1728           False           False                 False          False
#
#       auto_model_Tahoe  auto_model_Ultima  auto_model_Wrangler  auto_model_X5  \
# 0                False              False                False          False
# 1                False              False                 True          False
# 2                False              False                False          False
# 3                False              False                False          False
# 4                False              False                False          False
# ...                ...                ...                  ...            ...
# 1724             False               True                False          False
# 1725             False              False                False          False
# 1726             False              False                False          False
# 1727             False              False                False          False
# 1728             False              False                 True          False
#
#       auto_model_X6
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 1724          False
# 1725          False
# 1726          False
# 1727          False
# 1728          False
#
# [1729 rows x 179 columns]

# %%
df.to_csv("encoded_smoten.csv")
