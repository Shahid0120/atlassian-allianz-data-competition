# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_blobs
from sklearn.preprocessing import OrdinalEncoder

from imblearn.metrics.pairwise import ValueDifferenceMetric
from imblearn.over_sampling import SMOTEN

# %%
df = pd.read_csv("df_imputed.csv")
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  months_as_customer  age  policy_number  \
# 0                0           0                 267   40         426708
# 1                1           1                 322   44         769602
# 2                2           2                 259   45         608443
# 3                3           3                 446   61         259792
# 4                4           4                 134   29         687698
# ...            ...         ...                 ...  ...            ...
# 1724          1724        1724                  85   25         159768
# 1725          1725        1725                 131   33         432740
# 1726          1726        1726                 194   35         275092
# 1727          1727        1727                 210   37         218684
# 1728          1728        1728                  86   28         613226
#
#      policy_bind_date policy_state policy_csl  policy_deductable  \
# 0          2009-10-09           IL    250/500                500
# 1          2004-12-19           IL    100/300               1000
# 2          2006-12-21           IL   500/1000               2000
# 3          1999-04-07           IL    100/300               1000
# 4          2000-09-06           OH    100/300               2000
# ...               ...          ...        ...                ...
# 1724       2008-09-03           IN    250/500                500
# 1725       1990-10-09           IL    100/300               2000
# 1726       2012-03-14           IL   500/1000                500
# 1727       2006-08-05           IN   500/1000               2000
# 1728       1991-08-22           IN    100/300               2000
#
#       policy_annual_premium  ...  police_report_available  total_claim_amount  \
# 0                   1155.53  ...                       NO                5670
# 1                   1156.19  ...                        ?               49400
# 2                   1175.07  ...                       NO               87780
# 3                   1232.79  ...                      YES               70500
# 4                   1413.14  ...                       NO               34650
# ...                     ...  ...                      ...                 ...
# 1724                1259.02  ...                        ?                5640
# 1725                1081.17  ...                       NO                4900
# 1726                1416.24  ...                        ?                5940
# 1727                1048.46  ...                        ?                7080
# 1728                1595.07  ...                      YES               70920
#
#      injury_claim property_claim vehicle_claim auto_make  auto_model  \
# 0            1260            630          3780      Ford        F150
# 1            9880           4940         34580      Jeep    Wrangler
# 2            7980           7980         71820     Honda         CRV
# 3            7050          14100         49350    Suburu   Forrestor
# 4            7700           3850         23100     Dodge         RAM
# ...           ...            ...           ...       ...         ...
# 1724          940            940          3760    Nissan      Ultima
# 1725          490            490          3920    Toyota       Camry
# 1726         1080            540          4320    Nissan  Pathfinder
# 1727         1180            590          5310     Dodge         RAM
# 1728        11820          11820         47280      Jeep    Wrangler
#
#       auto_year  fraud_reported _c39
# 0          1997               N  NaN
# 1          2010               N  NaN
# 2          2011               N  NaN
# 3          2007               N  NaN
# 4          2007               N  NaN
# ...         ...             ...  ...
# 1724       2005               N  NaN
# 1725       2010               N  NaN
# 1726       2003               N  NaN
# 1727       1999               N  NaN
# 1728       2002               N  NaN
#
# [1729 rows x 42 columns]

# %%
# Drop columns
df = df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'capital-loss','_c39'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1729 entries, 0 to 1728
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1729 non-null   int64
#  1   age                          1729 non-null   int64
#  2   policy_number                1729 non-null   int64
#  3   policy_bind_date             1729 non-null   object
#  4   policy_state                 1729 non-null   object
#  5   policy_csl                   1729 non-null   object
#  6   policy_deductable            1729 non-null   int64
#  7   policy_annual_premium        1729 non-null   float64
#  8   umbrella_limit               1729 non-null   int64
#  9   insured_zip                  1729 non-null   int64
#  10  insured_sex                  1729 non-null   object
#  11  insured_education_level      1729 non-null   object
#  12  insured_occupation           1729 non-null   object
#  13  insured_hobbies              1729 non-null   object
#  14  insured_relationship         1729 non-null   object
#  15  capital-gains                1729 non-null   int64
#  16  incident_date                1729 non-null   object
#  17  incident_type                1729 non-null   object
#  18  collision_type               1729 non-null   object
#  19  incident_severity            1729 non-null   object
#  20  authorities_contacted        1729 non-null   object
#  21  incident_state               1729 non-null   object
#  22  incident_city                1729 non-null   object
#  23  incident_location            1729 non-null   object
#  24  incident_hour_of_the_day     1729 non-null   int64
#  25  number_of_vehicles_involved  1729 non-null   int64
#  26  property_damage              1729 non-null   object
#  27  bodily_injuries              1729 non-null   int64
#  28  witnesses                    1729 non-null   int64
#  29  police_report_available      1729 non-null   object
#  30  total_claim_amount           1729 non-null   int64
#  31  injury_claim                 1729 non-null   int64
#  32  property_claim               1729 non-null   int64
#  33  vehicle_claim                1729 non-null   int64
#  34  auto_make                    1729 non-null   object
#  35  auto_model                   1729 non-null   object
#  36  auto_year                    1729 non-null   int64
#  37  fraud_reported               1729 non-null   object
# dtypes: float64(1), int64(16), object(21)
# memory usage: 513.4+ KB

# %%
X = df.drop(columns=['fraud_reported'])
y = df['fraud_reported']

# %%
# set up SMOTE
sampler = SMOTEN(
    sampling_strategy='auto', # samples only the minority class
    random_state=0,  # for reproducibility
    k_neighbors=5,
    n_jobs=4,
)

X_res, y_res = sampler.fit_resample(X, y)
# Out:
# /usr/local/lib/python3.10/dist-packages/imblearn/over_sampling/_smote/base.py:858: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(

# %%
X_res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e242d8e8e252> in <cell line: 1>()
# ----> 1 X_res
#
# NameError: name 'X_res' is not defined

# %%
y_res.value_counts()
# Out:
# fraud_reported
# N    1482
# Y    1482
# Name: count, dtype: int64

# %%
X_res["fraud_reported"] = y_res
X_res
# Out:
#       months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                    267   40         426708       2009-10-09           IL
# 1                    322   44         769602       2004-12-19           IL
# 2                    259   45         608443       2006-12-21           IL
# 3                    446   61         259792       1999-04-07           IL
# 4                    134   29         687698       2000-09-06           OH
# ...                  ...  ...            ...              ...          ...
# 2959                  66   26         235869       1991-07-11           IL
# 2960                 175   46         155604       1992-03-03           IN
# 2961                   8   28         137675       1996-07-29           OH
# 2962                  19   41         260845       1991-04-08           OH
# 2963                  41   25         315041       1992-01-15           IL
#
#      policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0       250/500                500                1155.53         5000000
# 1       100/300               1000                1156.19               0
# 2      500/1000               2000                1175.07               0
# 3       100/300               1000                1232.79               0
# 4       100/300               2000                1413.14         5000000
# ...         ...                ...                    ...             ...
# 2959    250/500                500                 988.29               0
# 2960   500/1000                500                 920.30               0
# 2961    100/300               2000                1257.36               0
# 2962    250/500                500                 840.81               0
# 2963    100/300               2000                 998.19               0
#
#       insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0          465158  ...         2                      NO               5670
# 1          606249  ...         3                       ?              49400
# 2          457121  ...         1                      NO              87780
# 3          441967  ...         0                     YES              70500
# 4          430632  ...         3                      NO              34650
# ...           ...  ...       ...                     ...                ...
# 2959       464736  ...         2                      NO              44200
# 2960       437580  ...         1                     YES               5580
# 2961       463842  ...         1                      NO              51370
# 2962       435663  ...         2                      NO              40700
# 2963       435985  ...         0                       ?              35900
#
#      injury_claim property_claim  vehicle_claim auto_make auto_model  \
# 0            1260            630           3780      Ford       F150
# 1            9880           4940          34580      Jeep   Wrangler
# 2            7980           7980          71820     Honda        CRV
# 3            7050          14100          49350    Suburu  Forrestor
# 4            7700           3850          23100     Dodge        RAM
# ...           ...            ...            ...       ...        ...
# 2959            0           4420          32760      Audi         A5
# 2960          620            620           4340    Accura      Civic
# 2961         7020           4670          37360      Ford     Escape
# 2962         4070           4070          32560      Ford     Escape
# 2963            0           3590          25130    Accura         A3
#
#      auto_year fraud_reported
# 0         1997              N
# 1         2010              N
# 2         2011              N
# 3         2007              N
# 4         2007              N
# ...        ...            ...
# 2959      1996              Y
# 2960      1997              Y
# 2961      2000              Y
# 2962      1995              Y
# 2963      1996              Y
#
# [2964 rows x 38 columns]

# %%
X_res.to_csv('smoten.csv')

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
